# %% [markdown]
# Task #2 Demo

# %%
# !pip install -r requirements.txt

# %%
from inference import image_matching_algorithm

# %%
# PATH IMAGES contain the path to images
PATH_IMAGES = r"data\deforestation-in-ukraine\S2A_MSIL1C_20160212T084052_N0201_R064_T36UYA_20160212T084510\S2A_MSIL1C_20160212T084052_N0201_R064_T36UYA_20160212T084510.SAFE\GRANULE\L1C_T36UYA_A003350_20160212T084510\IMG_DATA"
image_matching_algorithm(PATH_IMAGES)
